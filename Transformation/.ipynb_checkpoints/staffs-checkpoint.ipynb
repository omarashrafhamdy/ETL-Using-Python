# %%
import pandas as pd

# %%
staffs = pd.read_csv('../staging_1/staffs/staffs.csv')
staffs
# Out:
#    staff_id  first_name last_name                          email  \
# 0         3       Genna   Serrano       genna.serrano@bikes.shop
# 1         4      Virgie   Wiggins      virgie.wiggins@bikes.shop
# 2         5    Jannette     David      jannette.david@bikes.shop
# 3         8        Kali    Vargas         kali.vargas@bikes.shop
# 4         9       Layla   Terrell       layla.terrell@bikes.shop
# 5        10  Bernardine   Houston  bernardine.houston@bikes.shop
#
#             phone  active  store_id  manager_id source  \
# 0  (831) 555-5556       1       1.0         2.0     DL
# 1  (831) 555-5557       1       1.0         2.0     DL
# 2  (516) 379-4444       1       2.0         1.0     DL
# 3  (972) 530-5555       1       3.0         1.0     DL
# 4  (972) 530-5556       1       3.0         7.0     DL
# 5  (972) 530-5557       1       3.0         7.0     DL
#
#               timestamp_saved
# 0  2024-04-28 17:57:24.082613
# 1  2024-04-28 17:57:24.082613
# ...

# %%
staffs.to_csv('../staging_2/staffs/staffs.csv', index = False)
