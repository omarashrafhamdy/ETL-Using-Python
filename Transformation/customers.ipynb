# %%
import pandas as pd

# %%
customers = pd.read_csv('../staging_1/customers/customers.csv')
customers
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks             NaN
# 1               2       Kasha      Todd             NaN
# 2               3      Tameka    Fisher             NaN
# 3               4       Daryl    Spence             NaN
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison             NaN
# 1441         1442      Cassie     Cline             NaN
# 1442         1443      Lezlie      Lamb             NaN
# 1443         1444      Ivette     Estes             NaN
# 1444         1445       Ester   Acevedo             NaN
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
stores = pd.read_csv('../staging_1/stores/stores.csv')
stores
# Out:
#    store_id     store_name           phone               email  \
# 0         2  Baldwin Bikes  (516) 379-8888  baldwin@bikes.shop
# 1         3  Rowlett Bikes  (972) 530-5555  rowlett@bikes.shop
#
#                 street     city state  zip_code source  \
# 0   4200 Chestnut Lane  Baldwin    NY   11432.0     DL
# 1  8000 Fairway Avenue  Rowlett    TX   75088.0     DL
#
#               timestamp_saved
# 0  2024-04-30 11:21:51.814680
# 1  2024-04-30 11:21:51.814680

# %%
cities_with_stores = stores['city'].unique()
cities_with_stores
# Out:
# array(['Baldwin', 'Rowlett'], dtype=object)

# %%
customers['local'] = customers['city'].isin(cities_with_stores)
customers[customers['local'] == True]
# Out:
#       customer_id first_name   last_name phone  \
# 67             68      Jayne    Kirkland   NaN
# 78             79    Ashanti       Parks   NaN
# 159           160       Omer     Estrada   NaN
# 313           314     Javier     Nichols   NaN
# 314           315    Justina     Jenkins   NaN
# 412           413    Ginette     Edwards   NaN
# 450           451   Jennette      Wooten   NaN
# 472           473   Lashawna  Richardson   NaN
# 589           590      Cyndi        Dyer   NaN
# 656           657        Sam      Lester   NaN
# 807           808     Vallie       Dixon   NaN
# 849           850  Stephanie    Browning   NaN
# 996           997   Trinidad     Mcclain   NaN
# 1028         1029       Ping       Quinn   NaN
# 1063         1064      Patsy       Russo   NaN
#
#                                 email                  street     city state  \
# 67         jayne.kirkland@hotmail.com       7800 Second Lane   Rowlett    TX
# ...

# %%
customers.to_csv('../staging_2/customers/customers.csv', index = False)
